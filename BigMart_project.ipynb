# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Import Train dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65026f11-7319-4ba6-a0ff-179033482553" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65026f11-7319-4ba6-a0ff-179033482553">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Train = pd.read_csv("Train.csv")
Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Train.shape
# Out:
# (8523, 12)

# %%
Train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
Train.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Statistical Information
Train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Checking unique values in the data set
Train.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# ## Preprocessing the dataset

# %%
# Checking for Null values
Train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Checking how much percentage of null value each attribute contain
total = Train.isna().sum().sort_values(ascending=False)
percent = (Train.isna().sum()/Train.isna().count()*100).sort_values(ascending=False)
missing_data = pd.concat([total,percent],axis=1,keys=["Total","Percent"])
missing_data
# Out:
#                            Total    Percent
# Outlet_Size                 2410  28.276428
# Item_Weight                 1463  17.165317
# Item_Identifier                0   0.000000
# Item_Fat_Content               0   0.000000
# Item_Visibility                0   0.000000
# Item_Type                      0   0.000000
# Item_MRP                       0   0.000000
# Outlet_Identifier              0   0.000000
# Outlet_Establishment_Year      0   0.000000
# Outlet_Location_Type           0   0.000000
# Outlet_Type                    0   0.000000
# Item_Outlet_Sales              0   0.000000

# %%
# Check for numerical column
# We have only 1 integer column Outlet_Establishment_Year
num_col = []
for x in Train.dtypes.index:
    if Train.dtypes[x] == "float":
           num_col.append(x)
num_col
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']

# %%
# Check for categorical Attributes
cat_col = []
for x in Train.dtypes.index:
    if Train.dtypes[x] =="object":
           cat_col.append(x)
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
# Print Categorical Columns
for col in cat_col:
    print(col)
    print(Train[col].value_counts())
    print()
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Identifier
# OUT027    935
# OUT013    932
# ...

# %%
# fill the missing values of Item_Weight Based on the Item_Identifier Column
item_weight_mean = Train.pivot_table(values="Item_Weight" , index = "Item_Identifier")
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
# We need to check which row has the missing values and store it
miss_bool = Train["Item_Weight"].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
# Now lets fill the missing values
for i, item in enumerate(Train["Item_Identifier"]):
    if miss_bool[i]:
      if item in item_weight_mean :
        Train["Item_Weight"][i] = item_weight_mean.loc[item]["Item_weight"]
      else:
        Train["Item_Weight"][i] = np.mean(Train["Item_Weight"])

# %%
Train["Item_Weight"].isna().sum()
# Out:
# 0

# %%
# fill the missing values of Outlet_Size Based on the Outlet_Type
outlet_size_mode = Train.pivot_table(values="Outlet_Size", columns ="Outlet_Type", aggfunc =(lambda x: x.mode()[0]))
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
# now lets fill the missing values
miss_bool = Train["Outlet_Size"].isnull()
Train.loc[miss_bool , "Outlet_Size"] = Train.loc[miss_bool , "Outlet_Type"].apply(lambda x: outlet_size_mode[x])

# %%
Train["Outlet_Size"].isna().sum()
# Out:
# 0

# %%
# after filling all the null values now lets check for the null values in the dataset
Train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
sum(Train["Item_Visibility"]==0)
# Out:
# 526

# %%
# replace zeros with mean value of Item_visibility
Train.loc[:,"Item_Visibility"].replace([0], [Train["Item_Visibility"].mean()], inplace = True)

# %%
sum(Train["Item_Visibility"]==0)
# Out:
# 0

# %%
# LF,low fat = Low Fat
# reg = Regular
Train = Train.replace(to_replace = "low fat",value = "Low Fat")
Train = Train.replace(to_replace = "LF" , value= "Low Fat")
Train = Train.replace(to_replace = "reg" , value = "Regular")

# %%
Train["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
# Checking for duplicate values
Train.duplicated().sum()
# Out:
# 0

# %%
# Correlation matrix
Train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.011550        -0.134138  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.078355          -0.134138
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %% [markdown]
# ## Creation Of New Attributes

# %%
Train["New_Item_Type"] =Train["Item_Identifier"].apply(lambda x: x[:2])
Train["New_Item_Type"]
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
Train["New_Item_Type"] = Train["New_Item_Type"].replace({"FD":"Food" , "DR":"Drinks", "NC":"Non-Consumable"})
Train["New_Item_Type"].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Type, dtype: int64

# %%
Train.loc[Train["New_Item_Type"] == "Non-Consumable","Item_Fat_Content"] = "Non- Edible"
Train["Item_Fat_Content"].value_counts()
# Out:
# Low Fat        3918
# Regular        3006
# Non- Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
# Create small values for establishent year
Train["Outlet_Years"] = 2013 - Train["Outlet_Establishment_Year"]

# %%
Train["Outlet_Years"]
# Out:
# 0       14
# 1        4
# 2       14
# 3       15
# 4       26
#         ..
# 8518    26
# 8519    11
# 8520     9
# 8521     4
# 8522    16
# Name: Outlet_Years, Length: 8523, dtype: int64

# %% [markdown]
# # Checking unique value for categorical column individually

# %%
Train["Item_Identifier"].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
Train["Item_Fat_Content"].value_counts()
# Out:
# Low Fat        3918
# Regular        3006
# Non- Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
Train["Item_Type"].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
Train["Outlet_Identifier"].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
Train["Outlet_Size"].value_counts()
# Out:
# Small     4798
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
Train["Outlet_Location_Type"].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
Train["Outlet_Type"].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# #Visualization & Cleaning

# %%
# Visualizing the "Outlet_Identifier"
Train["Outlet_Identifier"].value_counts().plot(kind ="bar", color = "purple")
plt.show()

# %%
cat_col = Train.select_dtypes("object")

# %%
# Barplot for all the categorical columns based on the Avg Item_Outlet_Sales
for i in cat_col.columns:
    plt.figure(figsize=(12,6))
    sns.barplot(x=Train[i], y=Train.Item_Outlet_Sales, data=Train)
    plt.xticks(rotation=90)
    plt.title(f"Avg Outlet Sales Based on {i}")

# %% [markdown]
# ## Lets Check the Individual Object Variable

# %%
# Item_Fat_Content
# Visualizing Item_Fat_content
Train["Item_Fat_Content"].value_counts().plot(kind = "bar", color="green")
plt.show()

# %%
# Visualizing Item_Type
Train["Item_Type"].value_counts().plot(kind="bar" , color= "black")
plt.show()

# %% [markdown]
# By seeing the data we can say that in all the store the most selling Item is "Fruits and Vegetable" and the lowest selling item is "Seafood"

# %%
# Visualizing the Outlet_Size
Train["Outlet_Size"].value_counts().plot(kind = "bar" , color = "yellow")
plt.show()

# %%
# Visualizing Outlet_Location_Type
Train["Outlet_Location_Type"].value_counts().plot(kind = "bar", color = "red")
plt.show()

# %%
# Visualizing Outlet_Type
Train["Outlet_Type"].value_counts().plot(kind ="bar" , color = "blue")
plt.show()

# %%
# Visualizing Outlet_Establishment_Year
Train["Outlet_Establishment_Year"].value_counts().plot(kind ="bar" , color = "cyan")
plt.show()

# %% [markdown]
# ## Lets Check The Individual int/float Variable

# %% [markdown]
# ### Histogram & Distribution Plot

# %%
plt.hist(Train["Item_Weight"])
plt.xlabel("Item Weight")
plt.show()

# %%
sns.distplot(Train["Item_Weight"], hist = True, color = "red",label=f'Skew: {Train["Item_Weight"].skew():.2f} & Kurt: {Train["Item_Weight"].kurt():.2f}')
plt.legend()

# %%
plt.hist(Train["Item_Visibility"])
plt.xlabel("Item Visibility")
plt.show()

# %%
sns.distplot(Train["Item_Visibility"], hist = True, color = "red" ,label=f'Skew: {Train["Item_Visibility"].skew():.2f} & Kurt: {Train["Item_Visibility"].kurt():.2f}')
plt.legend()

# %%
plt.hist(Train["Item_MRP"])
plt.xlabel("Item MRP")
plt.show()

# %%
sns.distplot(Train["Item_MRP"],hist = True, color = "red" ,label=f'Skew: {Train["Item_MRP"].skew():.2f} & Kurt: {Train["Item_MRP"].kurt():.2f}')
plt.legend()

# %%
plt.hist(Train["Item_Outlet_Sales"])
plt.xlabel("Item Outlet Sales")
plt.show()

# %%
sns.distplot(Train["Item_Outlet_Sales"], hist = True , color = "red" , label=f'Skew: {Train["Item_Outlet_Sales"].skew():.2f} & Kurt: {Train["Item_Outlet_Sales"].kurt():.2f}')
plt.legend()

# %%
# Item_Outlet_Sales is very much right Skewd so we need to normalize it using Log Transformation
Train["Item_Outlet_Sales"] = np.log(1+Train["Item_Outlet_Sales"])

# %%
# After applying log transformation
sns.distplot(Train["Item_Outlet_Sales"], hist = True , color = "red" , label=f'Skew: {Train["Item_Outlet_Sales"].skew():.2f} & Kurt: {Train["Item_Outlet_Sales"].kurt():.2f}')
plt.legend()

# %% [markdown]
# BoxPlot

# %%
sns.boxplot(Train["Item_Weight"],color = "rosybrown")
plt.show()

# %%
sns.boxplot(Train["Item_Visibility"] ,color="plum")
plt.show()

# %%
Q1 = Train['Item_Visibility'].quantile(0.25)
Q3 = Train['Item_Visibility'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = Train[(Train['Item_Visibility'] < lower_bound) | (Train['Item_Visibility'] > upper_bound)]

# %%
outliers.head()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 49            FDS02    12.857645          Regular         0.255395
# 65            FDC46    17.700000          Low Fat         0.195068
# 83            NCL18    12.857645      Non- Edible         0.293418
# 108           DRE60    12.857645          Low Fat         0.278974
# 174           FDI32    17.700000          Low Fat         0.291865
#
#                  Item_Type  Item_MRP Outlet_Identifier  \
# 49                   Dairy  196.8794            OUT019
# 65             Snack Foods  185.4266            OUT010
# 83               Household  194.6136            OUT019
# 108            Soft Drinks  225.3720            OUT019
# 174  Fruits and Vegetables  115.1834            OUT010
#
#      Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 49                        1985       Small               Tier 1
# 65                        1998       Small               Tier 3
# ...

# %%
outliers.shape
# Out:
# (173, 14)

# %%
Train = Train.drop(outliers.index)

# %%
# After removing outliers
sns.boxplot(Train["Item_Visibility"] ,color ="teal")
plt.show()

# %%
sns.boxplot(Train["Item_MRP"], color = "aquamarine")
plt.show()

# %%
sns.boxplot(Train["Outlet_Establishment_Year"], color = "forestgreen")
plt.show()

# %%
sns.boxplot(Train["Item_Outlet_Sales"],color = "dimgrey")
plt.show()

# %%
q1 = Train['Item_Outlet_Sales'].quantile(0.25)
q3 = Train['Item_Outlet_Sales'].quantile(0.75)
IQR_s = q3 - q1

lower_bound = q1 - 1.5 * IQR_s
upper_bound = q3 + 1.5 * IQR_s

outlier = Train[(Train['Item_Outlet_Sales'] < lower_bound) | (Train['Item_Outlet_Sales'] > upper_bound)]

# %%
outlier.head()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 29            FDC14    12.857645          Regular         0.072222
# 133           FDS52     8.890000          Low Fat         0.009163
# 215           FDE10     6.670000          Regular         0.150555
# 236           FDS46    12.857645          Regular         0.082741
# 255           FDQ04    12.857645          Low Fat         0.148393
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 29         Canned   43.6454            OUT019                       1985
# 133  Frozen Foods  101.7016            OUT010                       1998
# 215   Snack Foods  130.0626            OUT010                       1998
# 236   Snack Foods  118.7782            OUT019                       1985
# 255  Frozen Foods   41.5796            OUT019                       1985
#
#     Outlet_Size Outlet_Location_Type    Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
outlier.shape
# Out:
# (200, 14)

# %%
Train = Train.drop(outlier.index)

# %%
# After Removing Outliers
sns.boxplot(Train["Item_Outlet_Sales"] , color = "coral")
plt.show()

# %% [markdown]
# StripPlot

# %%
plt.figure(figsize=(15, 6))

# Customizing the stripplot
sns.stripplot(x="Outlet_Type", y="Item_Outlet_Sales", hue="Item_Type", data=Train, jitter=True, dodge=True, alpha=1, palette="Set1")

# Adding titles and labels
plt.title('Strip Plot for Item_Outlet_Sales by Outlet_Type and Item_Type')
plt.xlabel('Outlet_Type')
plt.ylabel('Item_Outlet_Sales')

# Customizing the legend
plt.legend(title='Item_Type', bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# We are taking here Outlet Type and outlet sales plot based on the item type . By seeing this graph we can say that Grocery Store have the lowest sales and Supermarket type 1 and 3 have the maximum sales depend on the Item Type

# %%
# chi square test for checking correlation between outlet_size and Out_location_type
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(Train["Outlet_Type"], Train["Item_Type"])

# Display the contingency table
print("\nContingency Table:")
print(contingency_table)
# Out:
# Contingency Table:
# Item_Type          Baking Goods  Breads  Breakfast  Canned  Dairy  \
# Outlet_Type
# Grocery Store                52      23         12      50     61
# Supermarket Type1           425     160         68     421    450
# Supermarket Type2            68      27         12      77     72
# Supermarket Type3            69      31         11      72     67
#
# Item_Type          Frozen Foods  Fruits and Vegetables  Hard Drinks  \
# Outlet_Type
# Grocery Store                65                     97           10
# Supermarket Type1           572                    803          145
# Supermarket Type2            90                    134           22
# Supermarket Type3            89                    140           23
#
# Item_Type          Health and Hygiene  Household  Meat  Others  Seafood  \
# Outlet_Type
# Grocery Store                      49         92    51      19        7
# Supermarket Type1                 335        594   257     107       40
# ...

# %%
# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Display the results
print("\nChi-square statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square statistic: 31.779347916706314
# P-value: 0.9315429031274316

# %%
# Check if the result is statistically significant
alpha = 0.05
if p < alpha:
    print("\nReject the null hypothesis. There is a significant association between Outlet Type and Item Type.")
else:
    print("\nFail to reject the null hypothesis. There is no significant association between Outlet Type and Item Type.")
# Out:
# Fail to reject the null hypothesis. There is no significant association between Outlet Type and Item Type.

# %%
plt.figure(figsize=(12, 6))

# Customizing the stripplot
sns.stripplot(x="Outlet_Location_Type", y="Item_Outlet_Sales", hue="Outlet_Size", data = Train, jitter=True, dodge=True, alpha=1, palette="Set1")

# Adding titles and labels
plt.title('Strip Plot for "Outlet_Location_Type by Item_Outlet_Sales and Outlet_Size')
plt.xlabel('Outlet_Location_Type')
plt.ylabel('Item_Outlet_Sales')

# Customizing the legend
plt.legend(title='Outlet_Size', bbox_to_anchor=(1, 1), loc='upper left')

# %% [markdown]
# We are taking here outlet location type and item outlet sales plot based on the outlet size . By seeing the graph we can say In Tier 2 location all outlet size is small an in the Tier 1 location most of the outlet size is small and lesser than that there is alsho a pretty high number of medium size outlet and  in tier 3 location maximum outlet size is medium and high and also there is less number of small size outlet.

# %%
# chi square test for checking correlation between outlet_size and Out_location_type
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(Train["Outlet_Size"], Train["Outlet_Location_Type"])

# Display the contingency table
print("\nContingency Table:")
print(contingency_table)
# Out:
# Contingency Table:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3
# Outlet_Size
# High                       0       0     930
# Medium                   928       0    1855
# Small                   1281    2780     376

# %%
# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Display the results
print("\nChi-square statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square statistic: 5130.441710595585
# P-value: 0.0

# %%
# Check if the result is statistically significant
alpha = 0.05
if p < alpha:
    print("\nReject the null hypothesis. There is a significant association between Outlet Location Type and Outlet Size.")
else:
    print("\nFail to reject the null hypothesis. There is no significant association between Outlet Location Type and Outlet Size.")
# Out:
# Reject the null hypothesis. There is a significant association between Outlet Location Type and Outlet Size.

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(Train , hue = "Item_Type")
plt.show()

# %% [markdown]
# ## After cleaning the data and removing  Oitliers lets check the data

# %%
Train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930      Non- Edible         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600      Non- Edible         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
Train.shape
# Out:
# (8150, 14)

# %%
# Correlation matrix after cleaning the data
plt.figure(figsize=(10,7))
sns.heatmap(Train.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Train["Outlet"] = le.fit_transform(Train["Outlet_Identifier"])
cat_cols =["Item_Fat_Content","Item_Type","Outlet_Size","Outlet_Location_Type","Outlet_Type","New_Item_Type"]
for col in cat_cols:
    Train[col] = le.fit_transform(Train[col])

# %%
Train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 0         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            2
# 4   53.8614            OUT013                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  New_Item_Type  \
# ...

# %% [markdown]
# ##Now we are checking which column is more important and less important in our model building

# %%
target = Train.corr()["Item_Outlet_Sales"].abs().sort_values(ascending=False)
target*100
# Out:
# Item_Outlet_Sales            100.000000
# Item_MRP                      50.765556
# Outlet_Type                   40.369442
# Outlet                        19.706819
# Outlet_Size                   16.113219
# Item_Visibility                8.626266
# Outlet_Location_Type           6.180546
# Item_Fat_Content               1.753258
# Item_Type                      1.628364
# Outlet_Establishment_Year      0.737214
# Outlet_Years                   0.737214
# New_Item_Type                  0.657978
# Item_Weight                    0.482135
# Name: Item_Outlet_Sales, dtype: float64

# %%
high_imp_var = Train[["Item_MRP","Outlet_Type","Outlet","Outlet_Size"]]
high_imp_var.head()
# Out:
#    Item_MRP  Outlet_Type  Outlet  Outlet_Size
# 0  249.8092            1       9            1
# 1   48.2692            2       3            1
# 2  141.6180            1       9            1
# 3  182.0950            0       0            2
# 4   53.8614            1       1            0

# %%
medium_imp_var = Train[["Item_Visibility","Outlet_Location_Type","Item_Fat_Content","Item_Type"]]
medium_imp_var.head()
# Out:
#    Item_Visibility  Outlet_Location_Type  Item_Fat_Content  Item_Type
# 0         0.016047                     0                 0          4
# 1         0.019278                     2                 2         14
# 2         0.016760                     0                 0         10
# 3         0.066132                     2                 2          6
# 4         0.066132                     2                 1          9

# %%
low_imp_var =Train[["New_Item_Type","Item_Weight","Outlet_Years"]]
low_imp_var.head()
# Out:
#    New_Item_Type  Item_Weight  Outlet_Years
# 0              1         9.30            14
# 1              0         5.92             4
# 2              1        17.50            14
# 3              1        19.20            15
# 4              2         8.93            26

# %% [markdown]
# ##One-Hot_Encoding

# %%
Train = pd.get_dummies(Train, columns=['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'New_Item_Type'])
Train.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  Item_MRP  \
# 0           FDA15         9.30         0.016047          4  249.8092
# 1           DRC01         5.92         0.019278         14   48.2692
# 2           FDN15        17.50         0.016760         10  141.6180
# 3           FDX07        19.20         0.066132          6  182.0950
# 4           NCD19         8.93         0.066132          9   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0            OUT049                       1999           8.225808
# 1            OUT018                       2009           6.096776
# 2            OUT049                       1999           7.648868
# 3            OUT010                       1998           6.597664
# 4            OUT013                       1987           6.903451
#
#    Outlet_Years  Outlet  ...  Outlet_Location_Type_0  Outlet_Location_Type_1  \
# ...

# %% [markdown]
# #Input Split

# %%
X = Train.drop(columns =["Outlet_Establishment_Year","Item_Identifier","Outlet_Identifier","Item_Outlet_Sales"])
y = Train["Item_Outlet_Sales"]

# %%
X.head()
# Out:
#    Item_Weight  Item_Visibility  Item_Type  Item_MRP  Outlet_Years  Outlet  \
# 0         9.30         0.016047          4  249.8092            14       9
# 1         5.92         0.019278         14   48.2692             4       3
# 2        17.50         0.016760         10  141.6180            14       9
# 3        19.20         0.066132          6  182.0950            15       0
# 4         8.93         0.066132          9   53.8614            26       1
#
#    Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  Outlet_Size_0  \
# 0                   1                   0                   0              0
# 1                   0                   0                   1              0
# 2                   1                   0                   0              0
# 3                   0                   0                   1              0
# 4                   0                   1                   0              1
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)
scaled_X
# Out:
# array([[-0.83841074, -1.18696423, -0.77047276, ..., -0.32115452,
#          0.62759637, -0.48287358],
#        [-1.63243168, -1.11077127,  1.60581977, ...,  3.1137659 ,
#         -1.59338079, -0.48287358],
#        [ 1.08791226, -1.17015525,  0.65530276, ..., -0.32115452,
#          0.62759637, -0.48287358],
#        ...,
#        [-0.53301807, -0.73562002,  0.18004425, ..., -0.32115452,
#         -1.59338079,  2.07093542],
#        [-1.32938819,  1.85926243,  1.36819052, ..., -0.32115452,
#          0.62759637, -0.48287358],
#        [ 0.45363517, -0.5070585 ,  1.60581977, ...,  3.1137659 ,
#         -1.59338079, -0.48287358]])

# %%
scaled_X = pd.DataFrame(scaled_X, columns=X.columns)

# %%
scaled_X
# Out:
#       Item_Weight  Item_Visibility  Item_Type  Item_MRP  Outlet_Years  \
# 0       -0.838411        -1.186964  -0.770473  1.729529     -0.108953
# 1       -1.632432        -1.110771   1.605820 -1.523977     -1.308421
# 2        1.087912        -1.170155   0.655303 -0.017026     -0.108953
# 3        1.487272        -0.005843  -0.295214  0.636403      0.010994
# 4       -0.925330        -0.005843   0.417674 -1.433701      1.330409
# ...           ...              ...        ...       ...           ...
# 8145    -1.410435        -0.226307   1.368191  1.159876      1.330409
# 8146    -1.054535        -0.457437  -1.720990 -0.557195     -0.468793
# 8147    -0.533018        -0.735620   0.180044 -0.929048     -0.708687
# 8148    -1.329388         1.859262   1.368191 -0.638295     -1.308421
# 8149     0.453635        -0.507059   1.605820 -1.084917      0.130941
#
#         Outlet  Item_Fat_Content_0  Item_Fat_Content_1  Item_Fat_Content_2  \
# ...

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import cross_val_score,KFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train,X_test,y_train,y_test = train_test_split(scaled_X,y,test_size = 0.3,random_state = 110)

# %%
X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((5705, 22), (2445, 22), (5705,), (2445,))

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Training data prediction
pred_train = model.predict(X_train)
# Testing data prediction
pred_test = model.predict(X_test)

# %%
# calculate the mean squared error
mse_train = mean_squared_error(y_train , pred_train)
mse_test = mean_squared_error(y_test , pred_test)
print(f'Mean Squared Error for train data: {mse_train}')
print(f'Mean Squared Error for test data: {mse_test}')
# Out:
# Mean Squared Error for train data: 0.28255712247884907
# Mean Squared Error for test data: 0.2627995740157753

# %%
# Calculate the absolute errors
train_MAE = abs(pred_train - y_train)
test_MAE = abs(pred_test - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_MAE), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_MAE), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.41 degrees.
# Mean Absolute Error on test data : 0.4 degrees.

# %%
# MAPE
def MAPE(org,pred):
  mape = np.abs((org-pred)/org)*100
  return np.mean(mape)

# %%
mape_train = MAPE(y_train,pred_train)
mape_test = MAPE(y_test,pred_test)
print(f'Mean Absolute Percentage Error for train data: {mape_train}')
print(f'Mean Absolute Percentage Error for test data: {mape_test}')
# Out:
# Mean Absolute Percentage Error for train data: 5.82884805064417
# Mean Absolute Percentage Error for test data: 5.584955338018256

# %% [markdown]
# RMSE

# %%
rmse_train = mean_squared_error(y_train,pred_train,squared=False)
rmse_test = mean_squared_error(y_test,pred_test,squared=False)
print(f'Root Mean Square Error for train data: {rmse_train}')
print(f'Root Mean Square Error for test data: {rmse_test}')
# Out:
# Root Mean Square Error for train data: 0.5315610242284973
# Root Mean Square Error for test data: 0.5126398092381973

# %% [markdown]
# R^2 score

# %%
# Checking the accuracy
from sklearn.metrics import r2_score
R2_train= r2_score(y_train ,pred_train)
R2_test= r2_score(y_test,pred_test)

print(f'depend on the train data accuracy is: {R2_train}')
print(f'depend on the test data accuracy is : {R2_test}')
# Out:
# depend on the train data accuracy is: 0.6442943485730515
# depend on the test data accuracy is : 0.6611839931619935

# %% [markdown]
# ##Adjusted R^2

# %%
# Calculate the number of predictors
num_predictors = X.shape[1]
num_predictors
# Out:
# 22

# %%
# calculate the Adjusted R^2
n = len(y_train)
m = len(y_test)
adj_r2_train = 1 - ((1 - R2_train) * (n - 1) / (n - num_predictors - 1))
adj_r2_test = 1 - ((1 - R2_test) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_train}")
print(f"Ajusted R-squared test data : {adj_r2_test}")
# Out:
# Ajusted R-squared for train data : 0.642917100362669
# Ajusted R-squared test data : 0.658106391118048

# %%
# putting together the coefficient and their corresponding variable names
lreg_coefficient = pd.DataFrame()
lreg_coefficient["Columns"] = X_train.columns
lreg_coefficient['Coefficient Estimate'] = pd.Series(model.coef_)
print(lreg_coefficient)
# Out:
#                    Columns  Coefficient Estimate
# 0              Item_Weight         -5.974774e-03
# 1          Item_Visibility         -2.451802e-03
# 2                Item_Type          8.818347e-03
# 3                 Item_MRP          4.898867e-01
# 4             Outlet_Years         -6.767167e-01
# 5                   Outlet          1.840908e-01
# 6       Item_Fat_Content_0          5.063763e+11
# 7       Item_Fat_Content_1         -2.650284e+12
# 8       Item_Fat_Content_2          4.852866e+11
# 9            Outlet_Size_0          3.507249e+12
# 10           Outlet_Size_1          5.230930e+12
# 11           Outlet_Size_2          5.493684e+12
# 12  Outlet_Location_Type_0         -5.785124e+12
# 13  Outlet_Location_Type_1         -6.170134e+12
# 14  Outlet_Location_Type_2         -6.341676e+12
# 15           Outlet_Type_0         -2.463805e+11
# 16           Outlet_Type_1         -4.017253e+11
# 17           Outlet_Type_2         -2.731960e+11
# ...

# %%
sns.barplot (x="Coefficient Estimate", y= "Columns", data = lreg_coefficient)
plt.show()

# %% [markdown]
# ##Evaluate the model using KFold Cross validation

# %%
# using Kfold cross validation we are splitting the data into 5 splits
kfold = KFold(n_splits = 5)
model = LinearRegression()
results = cross_val_score(model, scaled_X,y,cv=kfold)
results
# Out:
# array([0.65199778, 0.63843887, 0.63554487, 0.65263937, 0.66072573])

# %%
# Accuracy of the model
r2_acc = results.mean()*100
r2_acc
# Out:
# 64.78693229734151

# %%
std_deviation_LR = np.std(results)*100
std_deviation_LR
# Out:
# 0.9443626276807779

# %%
# Calculating the adjusted R^2 accuracy
# Calculate the number of predictors
num_predictors = X.shape[1]

n = len(y)
adj_r2 = 1 - ((1 - r2_acc) * (n - 1) / (n - num_predictors - 1))
print(f"Ajusted R-squared : {adj_r2}")
# Out:
# Ajusted R-squared : 64.95960517916032

# %%
# Mean squared error for every 5 split
errors = cross_val_score(model,scaled_X,y,cv = kfold , scoring = "neg_mean_squared_error")
errors =  -errors
errors
# Out:
# array([0.27840915, 0.28867821, 0.26931728, 0.27845387, 0.27260558])

# %%
errors.mean()*100
# Out:
# 27.74928168516106

# %% [markdown]
# ## Ridge Regression

# %%
# Import ridge regression from sklearn library
from sklearn.linear_model import Ridge

# Train the model
ridgeR = Ridge(alpha = 5)
ridgeR.fit(X_train , y_train)
# predict for train data set
train_pred = ridgeR.predict(X_train)
# predict for test data set
test_pred = ridgeR.predict(X_test)

# %% [markdown]
# Mean-Squared-error

# %%
# calculate the mean squared error
mse_Rtrain = mean_squared_error(y_train , train_pred)
mse_Rtest = mean_squared_error(y_test , test_pred)
print(f'Mean Squared Error for train data: {mse_Rtrain}')
print(f'Mean Squared Error for test data: {mse_Rtest}')
# Out:
# Mean Squared Error for train data: 0.2827272329756452
# Mean Squared Error for test data: 0.26294308222126883

# %%
# Calculate the absolute errors
train_RMAE = abs(pred_train - y_train)
test_RMAE = abs(pred_test - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_RMAE), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_RMAE), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.41 degrees.
# Mean Absolute Error on test data : 0.4 degrees.

# %% [markdown]
# MAPE

# %%
mape_train_R = MAPE(y_train ,train_pred)
mape_test_R = MAPE(y_test,test_pred)
print(f'Mean Absolute Percentage  Error for train data: {mape_train_R}')
print(f'Mean Absolute Percentage Error for test data: {mape_test_R}')
# Out:
# Mean Absolute Percentage  Error for train data: 5.831777760186706
# Mean Absolute Percentage Error for test data: 5.590728542792421

# %% [markdown]
# RMSE

# %%
rmse_train_R = mean_squared_error(y_train ,train_pred,squared=False)
rmse_test_R = mean_squared_error(y_test,test_pred,squared=False)
print(f'Root Mean Square  Error for train data: {rmse_train_R}')
print(f'Root Mean Square Error for test data: {rmse_test_R}')
# Out:
# Root Mean Square  Error for train data: 0.5317210104703831
# Root Mean Square Error for test data: 0.5127797599567175

# %%
# Checking the ridge regression accuracy
r2_Rtrain= r2_score(y_train ,train_pred)
r2_Rtest= r2_score(y_test,test_pred)

print(f'depend on the train data accuracy is: {r2_Rtrain}')
print(f'depend on the test data accuracy is : {r2_Rtest}')
# Out:
# depend on the train data accuracy is: 0.6440801997859085
# depend on the test data accuracy is : 0.6609989743037403

# %% [markdown]
# adjusted R^2

# %%
n = len(y_train)
m = len(y_test)
adj_r2_train = 1 - ((1 - r2_Rtrain) * (n - 1) / (n - num_predictors - 1))
adj_r2_test = 1 - ((1 - r2_Rtest) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_train}")
print(f"Ajusted R-squared test data : {adj_r2_test}")
# Out:
# Ajusted R-squared for train data : 0.6427021224179552
# Ajusted R-squared test data : 0.6579196916591005

# %% [markdown]
# Cross-Validation

# %%
cross_val_scores = cross_val_score(ridgeR, scaled_X, y, cv=5, scoring='r2')
cross_val_scores=abs(cross_val_scores)
cross_val_scores
# Out:
# array([0.65239118, 0.63773723, 0.6353757 , 0.65194478, 0.66060784])

# %%
r2_cv_R = (cross_val_scores).mean()*100
print(f"Cross Validation mean score for Ridge regression: {r2_cv_R}")
# Out:
# Cross Validation mean score for Ridge regression: 64.7611343848334

# %%
std_deviation_ridge = np.std(cross_val_scores)*100
std_deviation_ridge
# Out:
# 0.9568109787983876

# %%
# get ridge coefficient and print them
ridge_coefficient = pd.DataFrame()
ridge_coefficient["Columns"] = X_train.columns
ridge_coefficient["Coefficient Estimate"] = pd.Series(ridgeR.coef_)
print(ridge_coefficient)
# Out:
#                    Columns  Coefficient Estimate
# 0              Item_Weight             -0.006396
# 1          Item_Visibility             -0.004086
# 2                Item_Type              0.006474
# 3                 Item_MRP              0.487931
# 4             Outlet_Years             -0.193225
# 5                   Outlet              0.030664
# 6       Item_Fat_Content_0             -0.005584
# 7       Item_Fat_Content_1             -0.000702
# 8       Item_Fat_Content_2              0.006402
# 9            Outlet_Size_0              0.145972
# 10           Outlet_Size_1             -0.049615
# 11           Outlet_Size_2             -0.045948
# 12  Outlet_Location_Type_0              0.060479
# 13  Outlet_Location_Type_1              0.004176
# 14  Outlet_Location_Type_2             -0.059235
# 15           Outlet_Type_0             -0.402856
# 16           Outlet_Type_1              0.014765
# 17           Outlet_Type_2             -0.022188
# ...

# %%
sns.barplot (x="Coefficient Estimate", y= "Columns", data = ridge_coefficient)
plt.show()

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# train the model
lasso = Lasso(alpha=0.001)
lasso.fit(X_train , y_train)
# predict for train data set
pred_Ltrain = lasso.predict(X_train)
# predict for test data set
pred_Ltest= lasso.predict(X_test)

# %% [markdown]
# Mean-Squared_Error

# %%
# calculate the mean squared error
mse_Ltrain = mean_squared_error(y_train , pred_Ltrain)
mse_Ltest = mean_squared_error(y_test , pred_Ltest)
print(f'Mean Squared Error for train data: {mse_Ltrain}')
print(f'Mean Squared Error for test data: {mse_Ltest}')
# Out:
# Mean Squared Error for train data: 0.2829789425838473
# Mean Squared Error for test data: 0.2630820234252516

# %%
# Calculate the absolute errors
train_LMAE = abs(pred_train - y_train)
test_LMAE = abs(pred_test - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_LMAE), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_LMAE), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.41 degrees.
# Mean Absolute Error on test data : 0.4 degrees.

# %% [markdown]
# MAPE

# %%
mape_train_L = MAPE(y_train ,pred_Ltrain)
mape_test_L = MAPE(y_test , pred_Ltest)
print(f'Mean Absolute Percentage Error for train data: {mape_train_L}')
print(f'Mean Absolute Percentage Error for test data: {mape_test_L}')
# Out:
# Mean Absolute Percentage Error for train data: 5.834295580619158
# Mean Absolute Percentage Error for test data: 5.593794215294665

# %% [markdown]
# RMSE

# %%
rmse_train_L = mean_squared_error(y_train ,pred_Ltrain)
rmse_test_L = mean_squared_error(y_test , pred_Ltest)
print(f'Root Mean Square Error for train data: {rmse_train_L}')
print(f'Root Mean Square Error for test data: {rmse_test_L}')
# Out:
# Root Mean Square Error for train data: 0.2829789425838473
# Root Mean Square Error for test data: 0.2630820234252516

# %%
# Checking the Lasso regression accuracy
r2_Ltrain= r2_score(y_train ,pred_Ltrain)
r2_Ltest= r2_score(y_test,pred_Ltest)

print(f'depend on the train data accuracy is: {r2_Ltrain}')
print(f'depend on the test data accuracy is : {r2_Ltest}')
# Out:
# depend on the train data accuracy is: 0.6437633274686565
# depend on the test data accuracy is : 0.660819843480964

# %% [markdown]
# Adjusted R^2

# %%
n = len(y_train)
m = len(y_test)
adj_r2_trn = 1 - ((1 - r2_Ltrain) * (n - 1) / (n - num_predictors - 1))
adj_r2_tst = 1 - ((1 - r2_Ltest) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_trn}")
print(f"Ajusted R-squared test data : {adj_r2_tst}")
# Out:
# Ajusted R-squared for train data : 0.6423840232103514
# Ajusted R-squared test data : 0.657738933719024

# %% [markdown]
# Cross-Validation

# %%
cross_val_scores_L = cross_val_score(lasso, scaled_X, y, cv=5, scoring='r2')
cross_val_scores_L
# Out:
# array([0.65199174, 0.63744759, 0.63511481, 0.65183067, 0.66037635])

# %%
r2_cv_L = (cross_val_scores_L).mean()*100
print(f"Cross validation mean score for Lasso Regression :{r2_cv_L}")
# Out:
# Cross validation mean score for Lasso Regression :64.73522318474741

# %%
std_deviation_lasso = np.std(cross_val_scores_L)*100
std_deviation_lasso
# Out:
# 0.9581915255414714

# %%
# get Lasso coefficient and print them
lasso_coeff = pd.DataFrame()
lasso_coeff["Columns"] = X_train.columns
lasso_coeff['Coefficient Estimate'] = pd.Series(lasso.coef_)
print(lasso_coeff)
# Out:
#                    Columns  Coefficient Estimate
# 0              Item_Weight             -0.005229
# 1          Item_Visibility             -0.003058
# 2                Item_Type              0.005141
# 3                 Item_MRP              0.487396
# 4             Outlet_Years             -0.010336
# 5                   Outlet             -0.013619
# 6       Item_Fat_Content_0             -0.000000
# 7       Item_Fat_Content_1             -0.000000
# 8       Item_Fat_Content_2              0.010919
# 9            Outlet_Size_0             -0.000000
# 10           Outlet_Size_1              0.019446
# 11           Outlet_Size_2             -0.000000
# 12  Outlet_Location_Type_0              0.006544
# 13  Outlet_Location_Type_1              0.000000
# 14  Outlet_Location_Type_2             -0.009767
# 15           Outlet_Type_0             -0.504957
# 16           Outlet_Type_1              0.000000
# 17           Outlet_Type_2             -0.060714
# ...

# %%
sns.barplot (x="Coefficient Estimate", y= "Columns", data = lasso_coeff)
plt.show()

# %% [markdown]
# ##Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
# Transforming the features into polynomial features
poly_features = PolynomialFeatures(degree=2)

# %%
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.fit_transform(X_test)

# %%
X_train_poly.shape , X_test_poly.shape
# Out:
# ((5705, 276), (2445, 276))

# %%
# Building the model
poly_reg = LinearRegression()
poly_reg.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Train prediction
pred_train_P = poly_reg.predict(X_train_poly)
# Test prediction
pred_test_P = poly_reg.predict(X_test_poly)

# %% [markdown]
# Mean Squared Error

# %%
# calculate the mean squared error
mse_Ptrain = mean_squared_error(y_train ,pred_train_P)
mse_Ptest = mean_squared_error(y_test , pred_test_P)
print(f'Mean Squared Error for train data: {mse_Ptrain}')
print(f'Mean Squared Error for test data: {mse_Ptest}')
# Out:
# Mean Squared Error for train data: 0.2584942149103711
# Mean Squared Error for test data: 0.24893587797285263

# %%
# Calculate the absolute errors
train_PMAE = abs(pred_train_P - y_train)
test_PMAE = abs(pred_test_P - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_PMAE), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_PMAE), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.39 degrees.
# Mean Absolute Error on test data : 0.39 degrees.

# %% [markdown]
# MAPE

# %%
mape_train_P = np.mean(100 * (train_PMAE / y_train))
mape_test_P = np.mean(100 * (test_PMAE / y_test))
print(f'Mean Absolute Percentage Error for train data: {mape_train_P}')
print(f'Mean Absolute Percentage Error for test data: {mape_test_P}')
# Out:
# Mean Absolute Percentage Error for train data: 5.538588702583324
# Mean Absolute Percentage Error for test data: 5.427273298639614

# %% [markdown]
# RMSE

# %%
rmse_train_P =mean_squared_error(y_train ,pred_train_P,squared=False)
rmse_test_P =mean_squared_error(y_test,pred_test_P,squared=False)
print(f'Root Mean Square Error for train data: {rmse_train_P}')
print(f'Root Mean Square Error for test data: {rmse_test_P}')
# Out:
# Root Mean Square Error for train data: 0.5084232635416785
# Root Mean Square Error for test data: 0.4989347432008044

# %% [markdown]
# R Squared

# %%
# Checking the Lasso regression accuracy
r2_train_P= r2_score(y_train ,pred_train_P)
r2_test_P= r2_score(y_test,pred_test_P)

print(f'depend on the train data accuracy is: {r2_train_P}')
print(f'depend on the test data accuracy is : {r2_test_P}')
# Out:
# depend on the train data accuracy is: 0.674586673667467
# depend on the test data accuracy is : 0.6790578506477631

# %% [markdown]
# Adjusted R^2 score

# %%
n = len(y_train)
m = len(y_test)
adj_r2_trn = 1 - ((1 - r2_train_P) * (n - 1) / (n - 276- 1))
adj_r2_tst = 1 - ((1 - r2_test_P) * (m - 1) / (m - 276 - 1))

print(f"Ajusted R-squared for train data : {adj_r2_trn}")
print(f"Ajusted R-squared test data : {adj_r2_tst}")
# Out:
# Ajusted R-squared for train data : 0.6733267135866301
# Ajusted R-squared test data : 0.6761426040392787

# %% [markdown]
# Cross-Validation Score

# %%
X_poly = poly_features.fit_transform(X)
cross_val_scores_P = cross_val_score(poly_reg, X_poly, y, cv=5, scoring='r2')
cross_val_scores_P
# Out:
# array([0.66518884, 0.66116181, 0.66003009, 0.67159095, 0.6814699 ])

# %%
cross_val_scores_P = cross_val_score(poly_reg, X_poly, y, cv=5, scoring='r2')
r2_P = cross_val_scores_P.mean()*100
print(f"Cross validation score for Polynomial Regression: {r2_P}")
# Out:
# Cross validation score for Polynomial Regression: 66.78883191567935

# %%
std_deviation_poly = np.std(cross_val_scores_P)*100
std_deviation_poly
# Out:
# 0.7905110486266301

# %% [markdown]
# ##Random Forest Regressor

# %%
# Tuning the hyper parameters : n_estimators , max_depth , min_samples_split , min_samples_leaf
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators": [200,400,600],
    "max_depth": [None,10,20,30],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4],
}

rf_regressor = RandomForestRegressor()

# GridSearchCV to find the best hyperparametrs
grid_search = GridSearchCV(rf_regressor, param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [200, 400, 600]})

# %%
# Best hyperparametrs
best_params = grid_search.best_params_
print(f"Best Hyperparametrs: {best_params}")
# Out:
# Best Hyperparametrs: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 600}

# %%
# build the model
rf = RandomForestRegressor(n_estimators= 600 , min_samples_split= 10 , min_samples_leaf= 4 , max_depth= 10 , random_state = 110)
# train the model on training data
rf.fit(X_train , y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                       n_estimators=600, random_state=110)

# %%
# Use the forest's predict method on the train data
train_prediction = rf.predict(X_train)

# Use the forest's predict method on the train data
test_prediction = rf.predict(X_test)

# %%
# calculate the mean squared error
mse_RFtrain = mean_squared_error(y_train , train_prediction)
mse_RFtest = mean_squared_error(y_test , test_prediction)
print(f'Mean Squared Error for train data: {mse_RFtrain}')
print(f'Mean Squared Error for test data: {mse_RFtest}')
# Out:
# Mean Squared Error for train data: 0.1975643420380695
# Mean Squared Error for test data: 0.2514589678407423

# %%
# Calculate the absolute errors
train_errors = abs(train_prediction - y_train)
test_errors = abs(test_prediction - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_errors), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_errors), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.34 degrees.
# Mean Absolute Error on test data : 0.39 degrees.

# %%
# RMSE
rmse_train_RF =mean_squared_error(y_train ,train_prediction,squared=False)
rmse_test_RF =mean_squared_error(y_test,test_prediction,squared=False)
print(f'Root Mean Square Error for train data: {rmse_train_RF}')
print(f'Root Mean Square Error for test data: {rmse_test_RF}')
# Out:
# Root Mean Square Error for train data: 0.44448210541940775
# Root Mean Square Error for test data: 0.5014568454421001

# %% [markdown]
# MAPE

# %%
# Calculate mean absolute percentage error (MAPE)
mape_train_RF = np.mean(100 * (train_errors / y_train))
mape_test_RF = np.mean(100 * (test_errors / y_test))
print(f' Mean Absolute percentage Error for train data: {mape_train_RF}')
print(f' Mean Absolute percentage Error for test data: {mape_test_RF}')
# Out:
#  Mean Absolute percentage Error for train data: 4.798160213435512
#  Mean Absolute percentage Error for test data: 5.443437487345291

# %%
# Calculate and display accuracy
accuracy_train = 100 - (mape_train_RF)
accuracy_test = 100 - (mape_test_RF)

print('Accuracy for train:', round(accuracy_train, 2), '%.')
print('Accuracy for test:', round(accuracy_test, 2), '%.')
# Out:
# Accuracy for train: 95.2 %.
# Accuracy for test: 94.56 %.

# %%
# R^2 score
r2_RFtrain = r2_score(y_train ,train_prediction)
r2_RFtest = r2_score(y_test , test_prediction)
print(f"R^2 score for train : {r2_RFtrain}")
print(f"R^2 score for test : {r2_RFtest}")
# Out:
# R^2 score for train : 0.7512901024512364
# R^2 score for test : 0.6758049411362717

# %% [markdown]
# Adjusted R^2 score

# %%
n = len(y_train)
m = len(y_test)
adj_r2_RFtrn = 1 - ((1 - r2_RFtrain) * (n - 1) / (n - num_predictors - 1))
adj_r2_RFtst = 1 - ((1 - r2_RFtest) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_RFtrn}")
print(f"Ajusted R-squared test data : {adj_r2_RFtst}")
# Out:
# Ajusted R-squared for train data : 0.7503271285430926
# Ajusted R-squared test data : 0.6728601470425466

# %% [markdown]
# Cross Validation Score

# %%
cross_val_scores_RF = cross_val_score(rf, scaled_X, y, cv=5, scoring='r2')
cross_val_scores_RF
# Out:
# array([0.65679552, 0.65276656, 0.65115694, 0.66458372, 0.6722624 ])

# %%
cv_RF = (cross_val_scores_RF).mean()*100
print(f"Cross validation mean score for Random Forest Regressor :{cv_RF}")
# Out:
# Cross validation mean score for Random Forest Regressor :65.95130289735806

# %%
std_deviation_RF = np.std(cross_val_scores_RF)*100
std_deviation_RF
# Out:
# 0.7886472206684635

# %% [markdown]
# ##Decision Tree Regressor

# %%
# Tuning the hyper parameters : max_depth , min_samples_split , min_samples_leaf, max_leaf_nodes
from sklearn.tree import DecisionTreeRegressor

param_grid = {
    "max_depth": [None,10,20,30],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4],
    "max_leaf_nodes": [None, 10, 20, 30],
}

dt_regressor = DecisionTreeRegressor()

# GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(dt_regressor, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_leaf_nodes': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
# Best hyperparameters
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}

# %%
# build the model
dt = DecisionTreeRegressor( min_samples_split= 10 , min_samples_leaf= 1 , max_depth= 20 , random_state = 110 ,max_leaf_nodes= 20)
# train the model on training data
dt.fit(X_train , y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, max_leaf_nodes=20, min_samples_split=10,
#                       random_state=110)

# %%
# Use the DT predict method on the train data
train_prediction_DT = dt.predict(X_train)

# Use the DT predict method on the train data
test_prediction_DT = dt.predict(X_test)

# %%
# calculate the mean squared error
mse_DTtrain = mean_squared_error(y_train , train_prediction_DT)
mse_DTtest = mean_squared_error(y_test , test_prediction_DT)
print(f'Mean Squared Error for train data: {mse_DTtrain}')
print(f'Mean Squared Error for test data: {mse_DTtest}')
# Out:
# Mean Squared Error for train data: 0.2610609828661736
# Mean Squared Error for test data: 0.2530874180949807

# %%
# Calculate the absolute errors
train_DTerrors = abs(train_prediction_DT - y_train)
test_DTerrors = abs(test_prediction_DT - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_DTerrors), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_DTerrors), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.39 degrees.
# Mean Absolute Error on test data : 0.39 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape_train_DT = np.mean(100 * (train_DTerrors / y_train))
mape_test_DT = np.mean(100 * (test_DTerrors / y_test))
print(f' Mean Absolute percentage Error for train data: {mape_train_DT}')
print(f' Mean Absolute percentage Error for test data: {mape_test_DT}')
# Out:
#  Mean Absolute percentage Error for train data: 5.550008483026415
#  Mean Absolute percentage Error for test data: 5.468757283678342

# %%
# RMSE
rmse_train_DT =mean_squared_error(y_train ,train_prediction_DT,squared=False)
rmse_test_DT =mean_squared_error(y_test,test_prediction_DT,squared=False)
print(f'Root Mean Square Error for train data: {rmse_train_DT}')
print(f'Root Mean Square Error for test data: {rmse_test_DT}')
# Out:
# Root Mean Square Error for train data: 0.5109412714453331
# Root Mean Square Error for test data: 0.5030779443535373

# %%
# Calculate and display accuracy
accuracy_DTtrain = 100 - (mape_train_DT)
accuracy_DTtest = 100 - (mape_test_DT)

print('Accuracy for train:', round(accuracy_DTtrain, 2), '%.')
print('Accuracy for test:', round(accuracy_DTtest, 2), '%.')
# Out:
# Accuracy for train: 94.45 %.
# Accuracy for test: 94.53 %.

# %% [markdown]
# R square score

# %%
r2_DTtrain = r2_score(y_train ,train_prediction_DT)
r2_DTtest = r2_score(y_test , test_prediction_DT)
print(f"R^2 score for train : {r2_DTtrain}")
print(f"R^2 score for test : {r2_DTtest}")
# Out:
# R^2 score for train : 0.6713554195416791
# R^2 score for test : 0.6737054513842743

# %% [markdown]
# Adjusted R^2 score

# %%
n = len(y_train)
m = len(y_test)
adj_r2_DTtrn = 1 - ((1 - r2_DTtrain) * (n - 1) / (n - num_predictors - 1))
adj_r2_DTtst = 1 - ((1 - r2_DTtest) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_DTtrn}")
print(f"Ajusted R-squared test data : {adj_r2_DTtst}")
# Out:
# Ajusted R-squared for train data : 0.6700829484452195
# Ajusted R-squared test data : 0.6707415867808284

# %% [markdown]
# Cross Validation Score

# %%
cross_val_scores_DT = cross_val_score(dt, scaled_X, y, cv=5, scoring='r2')
cross_val_scores_DT
# Out:
# array([0.65393294, 0.65700838, 0.65618576, 0.67001737, 0.68230014])

# %%
cv_DT = (cross_val_scores_DT).mean()*100
print(f"Cross validation mean score for Decision Tree Regressor :{cv_DT}")
# Out:
# Cross validation mean score for Decision Tree Regressor :66.38889174312979

# %%
std_deviation_DT = np.std(cross_val_scores_DT)*100
std_deviation_DT
# Out:
# 1.0791969389701601

# %% [markdown]
# ##XGBoost Algorithm

# %%
import xgboost as xgb

# Create an XGBoost Regressor
xgb_regressor = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Define the hyperparameters to tune and their possible values
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [2, 4, 6],
    'gamma': [0, 0.1, 0.2]
}

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(xgb_regressor, param_grid, cv=5, verbose=1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
# Get the best hyperparameters
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}

# %%
# build the model
xgb_reg = xgb.XGBRegressor( learning_rate = 0.1 , n_estimators = 100 , max_depth= 2 , gamma = 0, random_state = 42)
# train the model on training data
xgb_reg.fit(X_train , y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Use the DT predict method on the train data
train_prediction_xgb = xgb_reg.predict(X_train)

# Use the DT predict method on the train data
test_prediction_xgb = xgb_reg.predict(X_test)

# %%
# calculate the mean squared error
mse_xgb_train = mean_squared_error(y_train , train_prediction_xgb)
mse_xgb_test = mean_squared_error(y_test , test_prediction_xgb)
print(f'Mean Squared Error for train data: {mse_xgb_train}')
print(f'Mean Squared Error for test data: {mse_xgb_test}')
# Out:
# Mean Squared Error for train data: 0.2544994906172742
# Mean Squared Error for test data: 0.2447518609328571

# %%
# Calculate the absolute errors
train_XGBerror = abs(train_prediction_xgb - y_train)
test_XGBerror = abs(test_prediction_xgb - y_test)
print('Mean Absolute Error on train data :', round(np.mean(train_XGBerror), 2), 'degrees.')
print('Mean Absolute Error on test data :', round(np.mean(test_XGBerror), 2), 'degrees.')
# Out:
# Mean Absolute Error on train data : 0.39 degrees.
# Mean Absolute Error on test data : 0.38 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape_train_xgb = np.mean(100 * (train_XGBerror / y_train))
mape_test_xgb = np.mean(100 * (test_XGBerror / y_test))
print(f' Mean Absolute percentage Error for train data: {mape_train_xgb}')
print(f' Mean Absolute percentage Error for test data: {mape_test_xgb}')
# Out:
#  Mean Absolute percentage Error for train data: 5.496286423589598
#  Mean Absolute percentage Error for test data: 5.392226694763272

# %%
# RMSE
rmse_train_xgb =mean_squared_error(y_train ,train_prediction_xgb,squared=False)
rmse_test_xgb =mean_squared_error(y_test,test_prediction_xgb,squared=False)
print(f'Root Mean Square Error for train data: {rmse_train_xgb}')
print(f'Root Mean Square Error for test data: {rmse_test_xgb}')
# Out:
# Root Mean Square Error for train data: 0.5044794253656676
# Root Mean Square Error for test data: 0.49472402502087676

# %%
# Calculate and display accuracy
accuracy_XGBtrain = 100 - (mape_train_xgb)
accuracy_XGBtest = 100 - (mape_test_xgb)

print('Accuracy for train:', round(accuracy_XGBtrain, 2), '%.')
print('Accuracy for test:', round(accuracy_XGBtest, 2), '%.')
# Out:
# Accuracy for train: 94.5 %.
# Accuracy for test: 94.61 %.

# %% [markdown]
# R Square Score

# %%
r2_XGBtrain = r2_score(y_train ,train_prediction_xgb)
r2_XGBtest = r2_score(y_test , test_prediction_xgb)
print(f"R^2 score for train : {r2_XGBtrain}")
print(f"R^2 score for test : {r2_XGBtest}")
# Out:
# R^2 score for train : 0.6796155541801268
# R^2 score for test : 0.6844521209822666

# %% [markdown]
# Adjusted R square Score

# %%
n = len(y_train)
m = len(y_test)
adj_r2_xgbtrn = 1 - ((1 - r2_XGBtrain) * (n - 1) / (n - num_predictors - 1))
adj_r2_xgbtst = 1 - ((1 - r2_XGBtest) * (m - 1) / (m - num_predictors - 1))

print(f"Ajusted R-squared for train data : {adj_r2_xgbtrn}")
print(f"Ajusted R-squared test data : {adj_r2_xgbtst}")
# Out:
# Ajusted R-squared for train data : 0.6783750653015563
# Ajusted R-squared test data : 0.6815858727005201

# %% [markdown]
#  Cross Validation Score

# %%
cross_val_scores_XGB = cross_val_score(xgb_reg, scaled_X, y, cv=5, scoring='r2')
cross_val_scores_XGB
# Out:
# array([0.66581784, 0.66609967, 0.66605517, 0.67755257, 0.68544694])

# %%
cv_XGB = (cross_val_scores_XGB).mean()*100
print(f"Cross validation mean score for XGBoost Regressor :{cv_XGB}")
# Out:
# Cross validation mean score for XGBoost Regressor :67.21944395091825

# %%
std_deviation_XGB = np.std(cross_val_scores_XGB)*100
std_deviation_XGB
# Out:
# 0.7997950944162835
